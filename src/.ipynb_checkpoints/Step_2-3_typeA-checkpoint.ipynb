# %%
import random
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn import manifold
from matplotlib import pyplot as plt

# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn')
plt.rcParams['font.sans-serif'] = ['Songti SC']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
# %matplotlib inline

# %%
# %store -r samples_data
# %store -r threshold
# %store -r cluster_3rd
cluster = cluster_3rd

# %%
# 对于每个类别进行判别
samples_features = cluster.iloc[:, 2:]
datetime_features = cluster[("时间", 'Unnamed: 1_level_1')]  # 时间性质
source_features = samples_features[samples_features.columns[[x for x in range(0, 7)]]]  # 原料性质
produc_features = samples_features[samples_features.columns[[x for x in range(7, 10)]]]  # 产品性质
manule_features = samples_features[samples_features.columns[[x for x in range(14, samples_features.shape[1])]]]  # 操作属性

# %%
# 计算 操作属性 间的 相关系数 矩阵进行降维
manule_features_corr = manule_features.corr(method='spearman').abs()
# 展示 属性间 相关关系 热力图
fig, ax = plt.subplots(figsize=(21, 21))
sns.heatmap(manule_features_corr.iloc[:30, :30], annot=True, linewidths=.5, ax=ax)  # 只取出前 30 个属性作为一个例子
# Out:
# <AxesSubplot:xlabel='None-None', ylabel='None-None'>

# %%
# Upper triangle of correlations
upper = manule_features_corr.where(np.triu(np.ones(manule_features_corr.shape), k=1).astype(np.bool))
# Select columns with correlations above threshold
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
print('There are %d columns to remove.' % (len(to_drop)))

# %%
manule_features = manule_features.drop(columns = to_drop)
manule_features.head()
# Out:
#     S-ZORB.CAL_H2.PV S-ZORB.PDI_2102.PV S-ZORB.PT_2801.PV S-ZORB.FC_2801.PV  \
#                  氢油比            反应过滤器压差             还原器压力         还原器流化氢气流量
# 291         0.287452          18.167657          2.471278        899.318635
# 290         0.281411          19.731644          2.470357        897.190810
# 289         0.271662          21.222581          2.468122        900.605437
# 269         0.262731          20.566409          2.544569        748.559427
# 223         0.253081          19.966240          2.543828        749.582570
#
#     S-ZORB.TE_2103.PV S-ZORB.SIS_PDT_2103B.PV S-ZORB.TC_2101.PV  \
#               反应器上部温度                 反应过滤器压差            反吹氢气温度
# 291        418.126585             1146.712825        245.595297
# 290        426.073785             1139.931525        244.869150
# 289        422.599438             1135.410600        244.989058
# 269        426.191720             1029.170075        244.950935
# 223        427.582328              719.490173        245.334815
#
#     S-ZORB.TE_2301.PV S-ZORB.PC_2105.PV S-ZORB.PC_5101.PV  ...  \
#                D105温度            反吹氢气压力            稳定塔顶压力  ...
# 291        314.345782          5.787791          0.650025  ...
# 290        327.983362          5.773250          0.650028  ...
# 289        328.234895          5.764419          0.650032  ...
# 269        323.212610          5.793443          0.649979  ...
# 223        253.411115          5.781409          0.660024  ...
#
#     S-ZORB.AT-0010.DACA.PV S-ZORB.AT-0011.DACA.PV S-ZORB.AT-0012.DACA.PV  \
#             S_ZORB AT-0010         S_ZORB AT-0011         S_ZORB AT-0012
# 291               1.639023               0.680290               0.212376
# 290               0.934155               0.672048               0.631722
# 289               1.164670               0.663611               0.465383
# 269               1.204120               0.672233               0.206034
# 223               0.601803               0.691694               0.494050
#
#     S-ZORB.AT-0013.DACA.PV S-ZORB.FT_1204.DACA.PV S-ZORB.CAL.LEVEL.PV  \
#             S_ZORB AT-0013            D-121含硫污水排量               反应器料位
# 291               0.390887              40.460422           81.575220
# 290               0.391916              32.564631           81.969863
# 289               0.391713              36.112131           82.069888
# 269               0.393873              48.846357           84.565961
# 223               1.448496              31.488768        18928.966250
#
#     S-ZORB.FT_1503.DACA.PV S-ZORB.FT_1504.DACA.PV S-ZORB.PC_1001A.PV cluster
#          8.0MPa氢气至循环氢压缩机入口      8.0MPa氢气至反吹氢压缩机出口        D101原料缓冲罐压力
# 291            1874.514075            2762.950200        -101.572745       3
# 290            1517.495708            2764.824700        -100.802975       3
# 289            1595.273582            2777.768125        -100.289790       3
# 269            1995.622750            2622.278900         -88.230023       3
# 223            2492.624575            2069.631050         -53.077075       3
#
# [5 rows x 158 columns]

# %%
print(source_features.reindex().shape)
print(produc_features.reindex().shape)
print(manule_features.reindex().shape)
# Out:
# (70, 7)
# (70, 3)
# (70, 158)

# %%
y = produc_features[('产品性质', 'RON损失\n（不是变量）')].to_numpy()
X = manule_features.to_numpy()

# %%
# 使用 T-SNE 进行数据降维
# X是特征，不包含target; X_tsne 是已经降维之后的特征
# 指定降维后的维数
re_dimension = int(manule_features.shape[1]/3)  # 需要调整的参数
relate_features = set()
max_iter = 60
num_iter = 0
tsne = manifold.TSNE(n_components=re_dimension, perplexity=6, n_iter=6000, init='pca', method="exact")
features_pool = list(set(manule_features.keys().to_numpy()))
choice_feature = random.choice(features_pool)

while len(relate_features) <= 30 and num_iter <= max_iter:
    X_tsne = tsne.fit_transform(manule_features[list(set(features_pool).difference(set(choice_feature)))].to_numpy())
    print(f"num_iter => {num_iter} 原始样本数据维度 {X.shape[-1]}. t-SNE降维后的数据维度 {X_tsne.shape[-1]}")
    tSNE_features = pd.DataFrame(data=X_tsne, columns=[f'feature_{x + 1}' for x in range(re_dimension)])
    tSNE_features_full = tSNE_features.join(samples_data[[('产品性质', 'RON损失\n（不是变量）')]])
    tSNE_features_full_corr = tSNE_features_full.corr(method='spearman').abs().replace(1.0, np.nan)
    tSNE_feature = tSNE_features_full_corr[('产品性质', 'RON损失\n（不是变量）')].idxmax()
    combine_features = manule_features[features_pool].join(pd.DataFrame(data=tSNE_features[[tSNE_feature]].values, columns=[('t-SNE', 'max-relative')]))
    combine_features_corr = combine_features.corr(method='spearman').abs().replace(1.0, np.nan)
    choice_feature = combine_features_corr[('t-SNE', 'max-relative')].idxmax()
    relate_features.add(choice_feature)
    features_pool.remove(choice_feature)
    num_iter += 1

print(relate_features)
# Out:
# num_iter => 0 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 1 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 2 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 3 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 4 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 5 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 6 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 7 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 8 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 9 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 10 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 11 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 12 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 13 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 14 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 15 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 16 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 17 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 18 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 19 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 20 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 21 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 22 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 23 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 24 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 25 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 26 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 27 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 28 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 29 原始样本数据维度 158. t-SNE降维后的数据维度 52
# num_iter => 30 原始样本数据维度 158. t-SNE降维后的数据维度 52
# {('S-ZORB.PT_6002.PV', '加热炉炉膛压力'), ('S-ZORB.AT-0010.DACA.PV', 'S_ZORB AT-0010'), ('S-ZORB.TE_9301.PV', '1.0MPa蒸汽进装置温度'), ('S-ZORB.PT_2801.PV', '还原器压力'), ('S-ZORB.FT_1001.PV', '催化汽油进装置总流量'), ('S-ZORB.FT_9301.PV', '蒸汽进装置流量'), ('S-ZORB.PDI_2102.PV', '反应过滤器压差'), ('S-ZORB.LT_9001.DACA', 'D-203底部液位'), ('S-ZORB.FC_5103.DACA', '稳定塔顶回流流量'), ('S-ZORB.FC_5202.PV', '精制汽油出装置流量'), ('S-ZORB.FT_9002.DACA', 'D203出口燃料气流量'), ('S-ZORB.TC_1606.PV', '反应器入口温度'), ('S-ZORB.SIS_PT_2602.PV', '再生器顶部/再生器接收器差压'), ('S-ZORB.PC_2902.DACA', '低压热氮气压力'), ('S-ZORB.LT_1501.DACA', 'D-122液位液位'), ('S-ZORB.LC_5102.DACA', 'D-201水包界位'), ('S-ZORB.PC_1301.PV', 'K101机出口压力'), ('S-ZORB.TE_5008.DACA', 'E-205壳程出口管温度'), ('S-ZORB.SIS_PDT_2103B.PV', '反应过滤器压差'), ('S-ZORB.LC_1202.PV', 'D121液面'), ('S-ZORB.PDT_2503.DACA', 'D-107底排放滑阀压差'), ('S-ZORB.AC_6001.PV', '加热炉氧含量'), ('S-ZORB.PDT_1002.DACA', 'P-101A入口过滤器差压'), ('S-ZORB.FT_2701.DACA', 'D-110蒸汽盘管入口流量'), ('S-ZORB.FT_2001.DACA', '紧急氢气去R-101流量'), ('S-ZORB.FT_9102.PV', '火炬气排放流量'), ('S-ZORB.PT_9001.PV', '燃料气进装置压力'), ('S-ZORB.AT-0001.DACA.PV', 'S_ZORB AT-0001'), ('S-ZORB.CAL_H2.PV', '氢油比'), ('S-ZORB.TE_1001.PV', '原料进装置温度'), ('S-ZORB.PC_6001.PV', '辐射室出口压力')}

# %%
# 增加题目要求的变量作为建模属性
model_features = manule_features[list(relate_features)].join(source_features[('原料性质', '辛烷值RON')])
model_features = model_features.join(datetime_features)
model_features.describe()
# Out:
#       S-ZORB.PT_6002.PV S-ZORB.AT-0010.DACA.PV S-ZORB.TE_9301.PV  \
#                 加热炉炉膛压力         S_ZORB AT-0010     1.0MPa蒸汽进装置温度
# count         70.000000              70.000000         70.000000
# mean          -0.344104               0.584263        199.966232
# std            0.071328               0.173606         12.552725
# min           -0.596307               0.524582        179.319410
# 25%           -0.387970               0.535672        192.096431
# 50%           -0.336077               0.540083        197.122294
# 75%           -0.299485               0.547486        205.899967
# max           -0.181439               1.639023        242.896460
#
#       S-ZORB.PT_2801.PV S-ZORB.FT_1001.PV S-ZORB.FT_9301.PV  \
#                   还原器压力        催化汽油进装置总流量           蒸汽进装置流量
# count         70.000000         70.000000         70.000000
# mean           2.513027         99.265325       1308.358227
# std            0.045973         29.147901        647.288580
# min            2.385966         45.785115        132.650740
# 25%            2.477097         81.808802        815.566660
# 50%            2.507298        104.399958       1276.538562
# 75%            2.544533        123.851459       1801.503087
# max            2.579971        135.770275       2541.211050
#
#       S-ZORB.PDI_2102.PV S-ZORB.LT_9001.DACA S-ZORB.FC_5103.DACA  \
#                  反应过滤器压差           D-203底部液位            稳定塔顶回流流量
# count          70.000000           70.000000           70.000000
# mean           24.359300           -1.340523        10535.356429
# std             3.989660            0.019777         3848.784639
# min            16.442973           -1.384816         3918.328575
# 25%            21.861591           -1.350830         7476.671806
# 50%            24.650413           -1.339628        10689.464250
# 75%            26.953404           -1.331693        13506.824562
# max            32.968053           -1.257835        19637.119500
#
#       S-ZORB.FC_5202.PV  ... S-ZORB.FT_2701.DACA S-ZORB.FT_2001.DACA  \
#               精制汽油出装置流量  ...       D-110蒸汽盘管入口流量        紧急氢气去R-101流量
# count         70.000000  ...           70.000000           70.000000
# mean         130.873941  ...           22.847782           17.611590
# std            8.741179  ...           16.484600           26.253764
# min          105.895370  ...            2.741461           -7.718605
# 25%          125.571050  ...           13.072641           -0.429337
# 50%          133.544230  ...           16.822931           -0.115823
# 75%          137.066182  ...           27.487400           48.599525
# max          140.919797  ...           59.834505           69.559780
#
#       S-ZORB.FT_9102.PV S-ZORB.PT_9001.PV S-ZORB.AT-0001.DACA.PV  \
#                 火炬气排放流量          燃料气进装置压力         S_ZORB AT-0001
# count      7.000000e+01         70.000000              70.000000
# mean       3.686522e+05          0.412938               3.222572
# std        1.663226e+06          0.018538               2.831875
# min        5.052370e+01          0.377404               0.498255
# 25%        1.586220e+02          0.403054               0.521800
# 50%        2.146344e+02          0.412091               3.489003
# 75%        2.518142e+02          0.419527               6.221774
# max        8.490662e+06          0.511091               7.155496
#
#       S-ZORB.CAL_H2.PV S-ZORB.TE_1001.PV S-ZORB.PC_6001.PV       原料性质  \
#                    氢油比           原料进装置温度           辐射室出口压力     辛烷值RON
# count        70.000000         70.000000         70.000000  70.000000
# mean          0.281929         58.328907         -0.145081  -1.088986
# std           0.020888          8.351507          0.014611   0.926559
# min           0.232117         35.880617         -0.152709  -3.207485
# 25%           0.270994         55.647009         -0.151857  -1.619016
# 50%           0.280574         59.863449         -0.151278  -1.165168
# 75%           0.298053         64.069603         -0.146000  -0.512761
# max           0.363003         73.201157         -0.085849   0.763687
#
#                       时间
#       Unnamed: 1_level_1
# count       7.000000e+01
# mean        1.557764e+18
# std         2.503313e+16
# min         1.498810e+18
# 25%         1.545854e+18
# 50%         1.567588e+18
# 75%         1.579788e+18
# max         1.588147e+18
#
# [8 rows x 33 columns]

# %%
weight_3rd = manule_features.shape[0]/samples_features.shape[0]
model_features_3rd = model_features
produc_features_3rd = produc_features
# %store model_features_3rd
# %store produc_features_3rd
# %store weight_3rd
# Out:
# Stored 'model_features_3rd' (DataFrame)
# Stored 'produc_features_3rd' (DataFrame)
# Stored 'weight_3rd' (float)
